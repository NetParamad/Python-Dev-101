# %%
import streamlit as st
st.title("Hello, World!")
st.write("Streamlit is awesome!")
# Out:
# 2024-09-20 17:12:18.156 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 17:12:18.208
# ...
#   command:
#
#     streamlit run /Users/netparamad/Documents/GitHub/Python-Dev-101/.venv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-09-20 17:12:18.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 17:12:18.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 17:12:18.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 17:12:18.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
